# %% [markdown]
# <a href="https://colab.research.google.com/github/Emilianaalia/RE202/blob/main/Emiliana_Quratu'ain_4222501063.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Pratikum week 3 (Functional In Python)**

# %% [markdown]
# ####**Format dasar function**

# %%
def nama_function():
    print("Hello, ini function pertama emil")
    print ("ini adalah blok kode function")

#Untuk menjalankan function, cukup panggil namanya
nama_function()
# Out:
# Hello, ini function pertama emil
# ini adalah blok kode function

# %% [markdown]
# ####**Function dengan parameter**

# %%
def sapa(nama):
    print(f"Halo, {nama}! Ada yang bisa dibantu?")

sapa("Emiliana")
# Out:
# Halo, Emiliana! Ada yang bisa dibantu?

# %%
def perkenalan (nama, umur, jenis_kelamin, status_lulus):
    print(f"Haii Saya, {nama}")
    print(f"Umur Saya adalah {umur} tahun")
    print(f"Jenis Kelamin Saya adalah {jenis_kelamin}")
    print(f"Status Lulus Saya adalah {status_lulus}")

perkenalan("Emiliana", 20, "Perempuan", False)
# Out:
# Haii Saya, Emiliana
# Umur Saya adalah 20 tahun
# Jenis Kelamin Saya adalah Perempuan
# Status Lulus Saya adalah False

# %%
perkenalan( "Emiliana", 20, "Perempuan", False)
# Out:
# Haii Saya, Emiliana
# Umur Saya adalah 20 tahun
# Jenis Kelamin Saya adalah Perempuan
# Status Lulus Saya adalah False

# %%
def tambah(a, b):
    return a + b

hasil = tambah(10, 3)

print(f"Hasil penjumlahan 10 + 3 adalah {hasil}")
# Out:
# Hasil penjumlahan 10 + 3 adalah 13

# %%
def hitung_luas_persegi(sisi):
    luas = sisi * sisi
    return luas

luas_persegi = hitung_luas_persegi(6)
print(f"Luas persegi dengan sisi 6 adalah: {luas_persegi}")
# Out:
# Luas persegi dengan sisi 6 adalah: 36

# %%
def hitung_luas_segitiga(alas, tinggi):
    luas = 0.5 * alas * tinggi
    return luas
luas_segitiga = hitung_luas_segitiga(12, 4)
print(f"Luas segitiga dengan alas 12 dan tinggi 4 adalah: ")
print(luas_segitiga)
# Out:
# Luas segitiga dengan alas 12 dan tinggi 4 adalah:
# 24.0

# %% [markdown]
# ####**Hands On**

# %%
def sapa(nama):
    print("Halo, " + nama + "!")

sapa("Emiliana Quratu'ain")
# Out:
# Halo, Emiliana Quratu'ain!

# %% [markdown]
# ####**Function dengan default parameter**

# %%
def sapa(nama="User"):
    print(f"Halo, {nama}")

sapa()
sapa("Emiliana Quratu'ain")
# Out:
# Halo, User
# Halo, Emiliana Quratu'ain

# %% [markdown]
# ####**Function dengan return value**

# %%
def tambah(a, b):
    return a + b

hasil = tambah(50, 22)
print(hasil)
# Out:
# 72

# %% [markdown]
# ####**Function dengan banyak parameter (Arbitrary Arguments)**

# %%
# *args untuk banyak argumen tanpa nama
def jumlahkan(*angka):
    return sum(angka)

print(jumlahkan(1, 5, 3, 4))
# Out:
# 13

# %%
# **kwargs untuk banyak argumen dengan nama
def Biodata(**data):
    for key, value in data.items():
        print(f"{key}: {value}")

Biodata(nama="Emiliana Quratu'ain", umur=20, kota="Batam")
# Out:
# nama: Emiliana Quratu'ain
# umur: 20
# kota: Batam

# %% [markdown]
# ####**Hands On**

# %%
# Function untuk menghitung luas lingkaran
def luas_lingkaran(jari_jari):
    pi = 3.14
    return pi * jari_jari ** 2

# Function untuk menghitung keliling lingkaran
def keliling_lingkaran(jari_jari):
    pi = 3.14
    return 2 * pi * jari_jari

print("Luas Lingkaran:", luas_lingkaran(20))
print("Keliling Lingkaran:", keliling_lingkaran(20))
# Out:
# Luas Lingkaran: 1256.0
# Keliling Lingkaran: 125.60000000000001

# %% [markdown]
# ##**Pratikum: Hands On Object Oriented Programming (OOP)**

# %%
# mendefinisikan kelas untuk membangun objek untuk mobil
class car :
    car_type = 'Sedan'
    color = 'pink'


print(car.car_type)
# Out:
# Sedan

# %% [markdown]
# ####**Membuat Objek suatu kelas**

# %%
# Buat objek berupa â€œmobil_ayahâ€ dari kelas mobil
mobil_ayah = car()

# print untuk melihat spesifikasi mobil_ayah
print("--- Informasi Mobil Ayah ---")
print("Jenis mobil ayah :", mobil_ayah.car_type)
print("Warna mobil ayah :", mobil_ayah.color)
# Out:
# --- Informasi Mobil Ayah ---
# Jenis mobil ayah : Sedan
# Warna mobil ayah : pink

# %% [markdown]
# ####**Default Constructor**

# %%
class Mobil:
    def __init__(self):
        self.jenis_mobil = "Sedan"
        self.warna_mobil = "Hitam"
        self.dapat_menyala = False

mobil_baru = Mobil()
print(mobil_baru.jenis_mobil)
# Out:
# Sedan

# %% [markdown]
# ####**Parameterized Constructor**

# %%
class Mobil:
    def __init__(self, jenis, warna, ada_aki):
        self.jenis_mobil = jenis
        self.warna_mobil = warna
        self.dapat_menyala = self.starter(ada_aki)

    def starter(self, aki):
        if aki:
            return True
        else:
            return False

# Membuat objek mobil_ayah dan mobil_adik dari konstruktor kelas
mobil_ayah = Mobil("sedan", "merah", True)
mobil_adik = Mobil("jeep", "hijau", False)

# %%
print(f"""
--- Informasi Mobil Ayah ---
Jenis mobil: {mobil_ayah.jenis_mobil}
Warna mobil: {mobil_ayah.warna_mobil}
Apakah menyala? {mobil_ayah.dapat_menyala}
"""
)

print(f"""
--- Informasi Mobil Adik ---
Jenis mobil: {mobil_adik.jenis_mobil}
Warna mobil: {mobil_adik.warna_mobil}
Apakah menyala? {mobil_adik.dapat_menyala}
"""
)
# Out:
# --- Informasi Mobil Ayah ---
# Jenis mobil: sedan
# Warna mobil: merah
# Apakah menyala? True
#
#
# --- Informasi Mobil Adik ---
# Jenis mobil: jeep
# Warna mobil: hijau
# Apakah menyala? False

# %% [markdown]
# ####**Hands On Buat suatu kelas bernama User**

# %%
# Membuat kelas User
class User:
    def __init__(self, username, email, umur):
        self.username = username
        self.email = email
        self.umur = umur

    def info_user(self):
        return f"Username: {self.username}, Email: {self.email}, Umur: {self.umur}"

# Membuat objek dari kelas User
user1 = User("Milkiytta", "aaanaemili@gmail.com", 20)

# Menampilkan informasi pengguna
print(user1.info_user())
# Out:
# Username: Milkiytta, Email: aaanaemili@gmail.com, Umur: 20

# %% [markdown]
# ####**Instance Variable**

# %%
# Membuat class Mobil

# Mobil tersebut akan menghabiskan 5 liter bensin setiap kilometernya

class Mobil:
    def __init__(self,jenis,warna,bensin = 100) :
        self.jenis_mobil = jenis
        self.warna_mobil = warna
        self.liter_bensin = bensin
        self.kilometer = 0

    def jalan_maju(self,jumlah_km) :
      # aksi apabila ada bensin (bensin tidak kurang dari sama dengan nol)
      if self.liter_bensin > 0 :
        # menghitung bensin yang masih tersisa untuk melakukan aksi
        sisa_bensin = self.liter_bensin - jumlah_km*5

        # apabila sisa bensin lebih dari nol
        if sisa_bensin > 0 :
            self.kilometer += jumlah_km
            self.liter_bensin = sisa_bensin
            print(f"mobil maju {jumlah_km} km, sekarang mobil berada di posisi {self.kilometer} km dari titik awal. Bensin tersisa tinggal {self.liter_bensin}")
        # apabila sisa bensin kurang dari nol
        else :
            self.kilometer += self.liter_bensin/5
            print(f"Bensin tidak cukup! Mobil hanya maju {self.liter_bensin/5} km. Sekarang mobil di posisi {self.kilometer} dari posisi awal. Bensin sudah habis!")
            self.liter_bensin -= jumlah_km*5

      # apabila bensin tidak ada (minus atau sama dengan nol, maka mobil tidak bisa melakukan aksi apa-apa)
      else :
            print(f"mobil tidak ada bensin, jadi tidak bisa maju!")

    def jalan_mundur(self,jumlah_km) :
      # aksi apabila ada bensin (bensin tidak kurang dari sama dengan nol)
        if self.liter_bensin > 0 :
            # menghitung bensin yang masih tersisa untuk melakukan aksi
                sisa_bensin = self.liter_bensin - jumlah_km*5

                # apabila sisa bensin lebih dari nol
                if sisa_bensin > 0 :
                    self.kilometer -= jumlah_km
                    self.liter_bensin = sisa_bensin
                    print(f"mobil maju {jumlah_km} km, sekarang mobil berada di posisi {self.kilometer} km dari titik awal. Bensin tersisa tinggal {self.liter_bensin}")
                # apabila sisa bensin kurang dari nol
                else :
                    self.kilometer -= self.liter_bensin/5
                    print(f"Bensin tidak cukup! Mobil hanya mundur {self.liter_bensin/5} km. Sekarang mobil di posisi {self.kilometer} dari posisi awal. Bensin sudah habis!")
                    self.liter_bensin -= jumlah_km*5

          # apabila bensin tidak ada (minus atau sama dengan nol,
          # maka mobil tidak bisa melakukan aksi apa-apa)
        else :
            print(f"mobil tidak ada bensin, jadi tidak bisa maju!")

    def isi_bensin(self):
        self.liter_bensin = 100
        print("bensin mobil sudah terisi penuh!")

# %% [markdown]
# ####**Hands On Buatlah class Lingkaran yang memiliki atribut : jari-jari 10 cm, pi = 3.14159 dengan method Luas Lingkaran dan Keliling Lingkaran**

# %%
class Lingkaran:
    def __init__(self, jari_jari):
        self.r = jari_jari
        self.pi = 3.14159

    def luas_lingkaran(self):
        # Rumus: pi * r * r
        return self.pi * (self.r ** 2)

    def keliling_lingkaran(self):
        # Rumus: 2 * pi * r
        return 2 * self.pi * self.r

# Membuat objek lingkaran dengan jari-jari 10 cm
lingkaran_emil = Lingkaran(10)

# Menampilkan hasil
print(f"Jari-jari: {lingkaran_emil.r} cm")
print(f"Luas Lingkaran: {lingkaran_emil.luas_lingkaran()} cm²")
print(f"Keliling Lingkaran: {lingkaran_emil.keliling_lingkaran()} cm")
# Out:
# Jari-jari: 10 cm
# Luas Lingkaran: 314.159 cm²
# Keliling Lingkaran: 62.8318 cm
